# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # Convolutional Neural Networks with Keras
#
# Estimated time needed **30** mins

# %% [markdown]
# In this lab, we will learn how to use the Keras library to build convolutional neural networks. We will also use the popular MNIST dataset and we will compare our results to using a conventional neural network.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build convolutional neural networks
# * Convolutional neural network with one set of convolutional and pooling layers
# * Convolutional neural network with two sets of convolutional and pooling layers

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#Import-Keras-and-Packages">Import Keras and Packages</a>
# 2. <a href="#Convolutional-Neural-Network-with-One-Set-of-Convolutional-and-Pooling-Layers">Convolutional Neural Network with One Set of Convolutional and Pooling Layers</a>
# 3. <a href="#Convolutional-Neural-Network-with-Two-Sets-of-Convolutional-and-Pooling-Layers">Convolutional Neural Network with Two Sets of Convolutional and Pooling Layers</a>
#
# </font>
# </div>

# %% [markdown]
# ### Install the necessary libraries

# %% [markdown]
# Let's start by installing the keras libraries and the packages that we would need to build a neural network.

# %%
# All Libraries required for this lab are listed below. The libraries need to be installed on Skills Network Labs. 
# If you run this notebook on a different environment, e.g. your desktop, you may want to install these.
# !pip install numpy==2.0.2
# !pip install pandas==2.2.2
# !pip install tensorflow_cpu==2.18.0
# !pip install matplotlib==3.9.2

# %% [markdown]
# #### Suppress the tensorflow warning messages
# We use the following code to  suppress the warning messages due to use of CPU architechture for tensoflow.
# You may want to **comment out** these lines if you are using the GPU architechture

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %% [markdown]
# ## Import Keras and Packages

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input
from keras.utils import to_categorical

# %% [markdown]
# When working with convolutional neural networks in particular, we will need additional packages.

# %%
from keras.layers import Conv2D # to add convolutional layers
from keras.layers import MaxPooling2D # to add pooling layers
from keras.layers import Flatten # to flatten data for fully connected layers

# %% [markdown]
# ## Convolutional Neural Network with One Set of Convolutional and Pooling Layers

# %%
# import data
from keras.datasets import mnist

# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# %% [markdown]
# Let's normalize the pixel values to be between 0 and 1

# %%
X_train = X_train / 255 # normalize training data
X_test = X_test / 255 # normalize test data

# %% [markdown]
# Next, let's convert the target variable into binary categories

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1] # number of categories

# %% [markdown]
# Next, let's define a function that creates our model. Let's start with one set of convolutional and pooling layers.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), strides=(1, 1), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Finally, let's call the function to create the model, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 37s - 124ms/step - accuracy: 0.9173 - loss: 0.2899 - val_accuracy: 0.9671 - val_loss: 0.1122
# Epoch 2/10
# 300/300 - 34s - 114ms/step - accuracy: 0.9737 - loss: 0.0915 - val_accuracy: 0.9802 - val_loss: 0.0627
# Epoch 3/10
# 300/300 - 33s - 111ms/step - accuracy: 0.9822 - loss: 0.0610 - val_accuracy: 0.9845 - val_loss: 0.0469
# Epoch 4/10
# 300/300 - 33s - 109ms/step - accuracy: 0.9861 - loss: 0.0472 - val_accuracy: 0.9863 - val_loss: 0.0413
# Epoch 5/10
# 300/300 - 32s - 107ms/step - accuracy: 0.9888 - loss: 0.0385 - val_accuracy: 0.9864 - val_loss: 0.0404
# Epoch 6/10
# 300/300 - 32s - 107ms/step - accuracy: 0.9906 - loss: 0.0312 - val_accuracy: 0.9858 - val_loss: 0.0432
# Epoch 7/10
# 300/300 - 32s - 108ms/step - accuracy: 0.9920 - loss: 0.0266 - val_accuracy: 0.9873 - val_loss: 0.0359
# Epoch 8/10
# 300/300 - 32s - 107ms/step - accuracy: 0.9932 - loss: 0.0220 - val_accuracy: 0.9858 - val_loss: 0.0390
# Epoch 9/10
# 300/300 - 32s - 107ms/step - accuracy: 0.9942 - loss: 0.0194 - val_accuracy: 0.9874 - val_loss: 0.0381
# Epoch 10/10
# 300/300 - 32s - 107ms/step - accuracy: 0.9955 - loss: 0.0151 - val_accuracy: 0.9886 - val_loss: 0.0376
# Accuracy: 0.9886000156402588
#  Error: 1.139998435974121

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# ## Convolutional Neural Network with Two Sets of Convolutional and Pooling Layers

# %% [markdown]
# Let's redefine our convolutional model so that it has two convolutional and pooling layers instead of just one layer of each.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Conv2D(8, (2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # Compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Now, let's call the function to create our new convolutional neural network, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 36s - 121ms/step - accuracy: 0.8583 - loss: 0.4788 - val_accuracy: 0.9587 - val_loss: 0.1491
# Epoch 2/10
# 300/300 - 34s - 115ms/step - accuracy: 0.9617 - loss: 0.1272 - val_accuracy: 0.9721 - val_loss: 0.0936
# Epoch 3/10
# 300/300 - 35s - 115ms/step - accuracy: 0.9732 - loss: 0.0875 - val_accuracy: 0.9784 - val_loss: 0.0689
# Epoch 4/10
# 300/300 - 35s - 116ms/step - accuracy: 0.9789 - loss: 0.0694 - val_accuracy: 0.9826 - val_loss: 0.0553
# Epoch 5/10
# 300/300 - 38s - 127ms/step - accuracy: 0.9822 - loss: 0.0578 - val_accuracy: 0.9847 - val_loss: 0.0472
# Epoch 6/10
# 300/300 - 39s - 131ms/step - accuracy: 0.9842 - loss: 0.0523 - val_accuracy: 0.9847 - val_loss: 0.0469
# Epoch 7/10
# 300/300 - 35s - 116ms/step - accuracy: 0.9857 - loss: 0.0463 - val_accuracy: 0.9861 - val_loss: 0.0429
# Epoch 8/10
# 300/300 - 36s - 120ms/step - accuracy: 0.9872 - loss: 0.0417 - val_accuracy: 0.9845 - val_loss: 0.0439
# Epoch 9/10
# 300/300 - 35s - 118ms/step - accuracy: 0.9877 - loss: 0.0390 - val_accuracy: 0.9874 - val_loss: 0.0397
# Epoch 10/10
# 300/300 - 35s - 116ms/step - accuracy: 0.9896 - loss: 0.0346 - val_accuracy: 0.9894 - val_loss: 0.0339
# Accuracy: 0.9894000291824341
#  Error: 1.0599970817565918

# %% [markdown]
# <h3>Practice Exercise 1</h3>

# %% [markdown]
# Let's see how batch size affects the time required and accuracy of the model training.
# For this, you can try to change batch_size to 1024 and check it's effect on accuracy

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 59/59 - 35s - 594ms/step - accuracy: 0.6503 - loss: 1.2863 - val_accuracy: 0.8927 - val_loss: 0.3795
# Epoch 2/10
# 59/59 - 34s - 574ms/step - accuracy: 0.9154 - loss: 0.2892 - val_accuracy: 0.9400 - val_loss: 0.2030
# Epoch 3/10
# 59/59 - 33s - 553ms/step - accuracy: 0.9471 - loss: 0.1815 - val_accuracy: 0.9588 - val_loss: 0.1385
# Epoch 4/10
# 59/59 - 33s - 556ms/step - accuracy: 0.9609 - loss: 0.1352 - val_accuracy: 0.9675 - val_loss: 0.1068
# Epoch 5/10
# 59/59 - 47s - 799ms/step - accuracy: 0.9670 - loss: 0.1114 - val_accuracy: 0.9723 - val_loss: 0.0879
# Epoch 6/10
# 59/59 - 46s - 780ms/step - accuracy: 0.9716 - loss: 0.0973 - val_accuracy: 0.9766 - val_loss: 0.0761
# Epoch 7/10
# 59/59 - 44s - 753ms/step - accuracy: 0.9744 - loss: 0.0868 - val_accuracy: 0.9782 - val_loss: 0.0708
# Epoch 8/10
# 59/59 - 44s - 749ms/step - accuracy: 0.9767 - loss: 0.0786 - val_accuracy: 0.9797 - val_loss: 0.0634
# Epoch 9/10
# 59/59 - 44s - 753ms/step - accuracy: 0.9786 - loss: 0.0721 - val_accuracy: 0.9812 - val_loss: 0.0599
# Epoch 10/10
# 59/59 - 34s - 579ms/step - accuracy: 0.9794 - loss: 0.0673 - val_accuracy: 0.9812 - val_loss: 0.0580
# Accuracy: 0.9811999797821045
#  Error: 1.8800020217895508

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# # build the model
# model = convolutional_model()
#
# # fit the model
# model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=1024, verbose=2)
#
# # evaluate the model
# scores = model.evaluate(X_test, y_test, verbose=0)
# print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# -->

# %% [markdown]
# <h3>Practice Exercise 2</h3>

# %% [markdown]
# Now, let's see how number of epochs  affect the time required and accuracy of the model training.
# For this, you can keep the batch_size=1024 and epochs=25 and check it's effect on accuracy

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/25
# 59/59 - 35s - 602ms/step - accuracy: 0.6292 - loss: 1.3116 - val_accuracy: 0.8806 - val_loss: 0.4118
# Epoch 2/25
# 59/59 - 33s - 553ms/step - accuracy: 0.9054 - loss: 0.3306 - val_accuracy: 0.9292 - val_loss: 0.2524
# Epoch 3/25
# 59/59 - 32s - 548ms/step - accuracy: 0.9340 - loss: 0.2266 - val_accuracy: 0.9515 - val_loss: 0.1745
# Epoch 4/25
# 59/59 - 33s - 560ms/step - accuracy: 0.9507 - loss: 0.1691 - val_accuracy: 0.9601 - val_loss: 0.1406
# Epoch 5/25
# 59/59 - 33s - 551ms/step - accuracy: 0.9609 - loss: 0.1340 - val_accuracy: 0.9705 - val_loss: 0.1054
# Epoch 6/25
# 59/59 - 33s - 558ms/step - accuracy: 0.9676 - loss: 0.1108 - val_accuracy: 0.9746 - val_loss: 0.0899
# Epoch 7/25
# 59/59 - 33s - 560ms/step - accuracy: 0.9711 - loss: 0.0984 - val_accuracy: 0.9763 - val_loss: 0.0809
# Epoch 8/25
# 59/59 - 34s - 568ms/step - accuracy: 0.9731 - loss: 0.0887 - val_accuracy: 0.9788 - val_loss: 0.0697
# Epoch 9/25
# 59/59 - 33s - 562ms/step - accuracy: 0.9757 - loss: 0.0808 - val_accuracy: 0.9789 - val_loss: 0.0670
# Epoch 10/25
# 59/59 - 33s - 557ms/step - accuracy: 0.9770 - loss: 0.0754 - val_accuracy: 0.9800 - val_loss: 0.0667
# Epoch 11/25
# 59/59 - 33s - 558ms/step - accuracy: 0.9786 - loss: 0.0703 - val_accuracy: 0.9805 - val_loss: 0.0626
# Epoch 12/25
# 59/59 - 33s - 556ms/step - accuracy: 0.9797 - loss: 0.0667 - val_accuracy: 0.9811 - val_loss: 0.0613
# Epoch 13/25
# 59/59 - 33s - 558ms/step - accuracy: 0.9807 - loss: 0.0633 - val_accuracy: 0.9820 - val_loss: 0.0566
# Epoch 14/25
# 59/59 - 41s - 691ms/step - accuracy: 0.9822 - loss: 0.0593 - val_accuracy: 0.9838 - val_loss: 0.0514
# Epoch 15/25
# 59/59 - 33s - 555ms/step - accuracy: 0.9828 - loss: 0.0570 - val_accuracy: 0.9841 - val_loss: 0.0501
# Epoch 16/25
# 59/59 - 33s - 556ms/step - accuracy: 0.9837 - loss: 0.0539 - val_accuracy: 0.9840 - val_loss: 0.0504
# Epoch 17/25
# 59/59 - 32s - 548ms/step - accuracy: 0.9837 - loss: 0.0535 - val_accuracy: 0.9844 - val_loss: 0.0487
# Epoch 18/25
# 59/59 - 32s - 550ms/step - accuracy: 0.9854 - loss: 0.0493 - val_accuracy: 0.9835 - val_loss: 0.0488
# Epoch 19/25
# 59/59 - 33s - 554ms/step - accuracy: 0.9851 - loss: 0.0487 - val_accuracy: 0.9857 - val_loss: 0.0446
# Epoch 20/25
# 59/59 - 33s - 557ms/step - accuracy: 0.9860 - loss: 0.0470 - val_accuracy: 0.9859 - val_loss: 0.0443
# Epoch 21/25
# 59/59 - 33s - 557ms/step - accuracy: 0.9862 - loss: 0.0463 - val_accuracy: 0.9845 - val_loss: 0.0475
# Epoch 22/25
# 59/59 - 33s - 553ms/step - accuracy: 0.9868 - loss: 0.0441 - val_accuracy: 0.9856 - val_loss: 0.0418
# Epoch 23/25
# 59/59 - 33s - 560ms/step - accuracy: 0.9875 - loss: 0.0417 - val_accuracy: 0.9856 - val_loss: 0.0454
# Epoch 24/25
# 59/59 - 33s - 553ms/step - accuracy: 0.9875 - loss: 0.0420 - val_accuracy: 0.9861 - val_loss: 0.0418
# Epoch 25/25
# 59/59 - 33s - 560ms/step - accuracy: 0.9877 - loss: 0.0400 - val_accuracy: 0.9861 - val_loss: 0.0412
# Accuracy: 0.9861000180244446
#  Error: 1.389998197555542

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# # build the model
# model = convolutional_model()
#
# # fit the model
# model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=1024, verbose=2)
#
# # evaluate the model
# scores = model.evaluate(X_test, y_test, verbose=0)
# print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
#
#
#     -->

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 3.0  | Aman  |  Updated the library versions to current |
# | 2020-09-21  | 2.0  | Srishti  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
